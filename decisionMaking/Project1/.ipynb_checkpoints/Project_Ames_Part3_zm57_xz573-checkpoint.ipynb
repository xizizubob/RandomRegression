# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import sklearn
from scipy import stats
import statsmodels.formula.api as sm

import matplotlib.pyplot as plt
from scipy.stats import skew
from scipy.stats.stats import pearsonr
from sklearn import linear_model
import patsy
import statsmodels.formula.api as smf

from sklearn.model_selection import train_test_split

# %config InlineBackend.figure_format = 'png' #set 'png' here when working on notebook
# %matplotlib inline

# %%
data = pd.read_excel("NewRawData.xlsx")

# %%
data['Exter Qual'] = data['Exter Qual'].replace('Ex', 5)
data['Exter Qual'] = data['Exter Qual'].replace('Gd', 4)
data['Exter Qual'] = data['Exter Qual'].replace('TA', 3)
data['Exter Qual'] = data['Exter Qual'].replace('Fa', 2)
data['Exter Qual'] = data['Exter Qual'].replace('Po', 1)
data['Exter Cond'] = data['Exter Cond'].replace('Ex', 5)
data['Exter Cond'] = data['Exter Cond'].replace('Gd', 4)
data['Exter Cond'] = data['Exter Cond'].replace('TA', 3)
data['Exter Cond'] = data['Exter Cond'].replace('Fa', 2)
data['Exter Cond'] = data['Exter Cond'].replace('Po', 1)
data['Bsmt Qual'] = data['Bsmt Qual'].replace('Ex', 5)
data['Bsmt Qual'] = data['Bsmt Qual'].replace('Gd', 4)
data['Bsmt Qual'] = data['Bsmt Qual'].replace('TA', 3)
data['Bsmt Qual'] = data['Bsmt Qual'].replace('Fa', 2)
data['Bsmt Qual'] = data['Bsmt Qual'].replace('Po', 1)
data['Bsmt Qual'] = data['Bsmt Qual'].replace('No Basement', 0)
data['Bsmt Cond'] = data['Bsmt Cond'].replace('Ex', 5)
data['Bsmt Cond'] = data['Bsmt Cond'].replace('Gd', 4)
data['Bsmt Cond'] = data['Bsmt Cond'].replace('TA', 3)
data['Bsmt Cond'] = data['Bsmt Cond'].replace('Fa', 2)
data['Bsmt Cond'] = data['Bsmt Cond'].replace('Po', 1)
data['Bsmt Cond'] = data['Bsmt Cond'].replace('No Basement', 0)

# %%
from pandas import ExcelWriter

writer = ExcelWriter('NewData.xlsx')
data.to_excel(writer,'Sheet1')
writer.save()

# %%
singlefeatures = data.columns[:-1]
features = list(singlefeatures)
for i in range(len(features)):
    features[i] = "".join(features[i].split())
    features[i] = features[i].replace('.','DOT')

# %%
singlefeatures = features
features.append('SalePrice')
data.columns = features
train, test = train_test_split(data, test_size=0.2)#it is not time-series data
train.to_csv('train.csv')
test.to_csv('test.csv')

# %%
singlefeatures = list(set(features)-{'SalePrice'})

# %%
X = patsy.dmatrix('+'.join(singlefeatures)+'-1',train)
Y = train['SalePrice']
lasso = linear_model.LassoCV(cv =10, alphas = [500]).fit(X,Y)
lassofeatures = np.array(singlefeatures)[np.abs(lasso.coef_)>1e-10]
print lassofeatures
# Out:
# [u'Neighborhood_NridgHt' u'OverallCond' u'GrLivArea' u'BsmtCond'
#  u'OverallQual' u'Neighborhood_Gilbert' u'TotalBsmtSF'
#  u'HouseStyle_1Story' u'Neighborhood_StoneBr' u'YrSold' u'BsmtQual'
#  u'BldgType_1Fam' u'GarageCars' u'YearBuilt' u'HouseStyle_2Story'
#  u'BedroomAbvGr' u'LotArea' u'LotShape_IR1' u'ExterQual'
#  u'Neighborhood_OldTown' u'Neighborhood_NoRidge' u'SaleType_New'
#  u'Neighborhood_Crawfor']

# %%
lm = smf.ols('SalePrice ~ '+' + '.join(lassofeatures), data=train).fit()
print 'Here is in-sample R-square:'+str(lm.rsquared)
rsq = 1. - np.sum((lm.predict(test)-test['SalePrice'])**2)/np.sum((
    test['SalePrice'].mean()-test['SalePrice'])**2)
print 'Here is the out-of-sample R-square:'+str(rsq)
# Out:
# Here is in-sample R-square:0.8402156172809604
# Here is the out-of-sample R-square:0.887839645654

# %%
data = pd.read_excel("NotRawData.xlsx")
train, test = train_test_split(data, test_size=0.2)#i
singlefeatures = data.columns[:-1]
features = list(singlefeatures)
for i in range(len(features)):
    features[i] = "".join(features[i].split())
    features[i] = features[i].replace('.','DOT')
data.columns = features

# %%
lm = smf.ols('SalePrice ~ '+' + '.join(singlefeatures), data=train).fit()
print 'Here is in-sample R-square:'+str(lm.rsquared)
rsq = 1. - np.sum((lm.predict(test)-test['SalePrice'])**2)/np.sum((
    test['SalePrice'].mean()-test['SalePrice'])**2)
print 'Here is the out-of-sample R-square:'+str(rsq)
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-322-1386a0cbed6b> in <module>()
# ----> 1 lm = smf.ols('SalePrice ~ '+' + '.join(singlefeatures), data=train).fit()
#       2 print 'Here is in-sample R-square:'+str(lm.rsquared)
#       3 rsq = 1. - np.sum((lm.predict(test)-test['SalePrice'])**2)/np.sum((
#       4     test['SalePrice'].mean()-test['SalePrice'])**2)
#       5 print 'Here is the out-of-sample R-square:'+str(rsq)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/statsmodels/base/model.pyc in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     153
#     154         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 155                                   missing=missing)
#     156         ((endog, exog), missing_idx, design_info) = tmp
#     157
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/statsmodels/formula/formulatools.pyc in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/highlevel.pyc in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/highlevel.pyc in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     163         return iter([data])
#     164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 165                                       NA_action)
#     166     if design_infos is not None:
#     167         return build_design_matrices(design_infos, data,
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/highlevel.pyc in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      60                 "ascii-only, or else upgrade to Python 3.")
#      61     if isinstance(formula_like, str):
# ---> 62         formula_like = ModelDesc.from_formula(formula_like)
#      63         # fallthrough
#      64     if isinstance(formula_like, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in from_formula(cls, tree_or_string)
#     163         else:
#     164             tree = parse_formula(tree_or_string)
# --> 165         value = Evaluator().eval(tree, require_evalexpr=False)
#     166         assert isinstance(value, cls)
#     167         return value
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_any_tilde(evaluator, tree)
#     219
#     220 def _eval_any_tilde(evaluator, tree):
# --> 221     exprs = [evaluator.eval(arg) for arg in tree.args]
#     222     if len(exprs) == 1:
#     223         # Formula was like: "~ foo"
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_minus(evaluator, tree)
#     247
#     248 def _eval_binary_minus(evaluator, tree):
# --> 249     left_expr = evaluator.eval(tree.args[0])
#     250     if tree.args[1].type == "ZERO":
#     251         return IntermediateExpr(True, tree.args[1], False,
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_minus(evaluator, tree)
#     247
#     248 def _eval_binary_minus(evaluator, tree):
# --> 249     left_expr = evaluator.eval(tree.args[0])
#     250     if tree.args[1].type == "ZERO":
#     251         return IntermediateExpr(True, tree.args[1], False,
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# ...
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_minus(evaluator, tree)
#     254         return IntermediateExpr(False, None, True, left_expr.terms)
#     255     else:
# --> 256         right_expr = evaluator.eval(tree.args[1])
#     257         terms = [term for term in left_expr.terms
#     258                  if term not in right_expr.terms]
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _eval_binary_div(evaluator, tree)
#     298     right_expr = evaluator.eval(tree.args[1])
#     299     terms = list(left_expr.terms)
# --> 300     _check_interactable(left_expr)
#     301     # Build a single giant combined term for everything on the left:
#     302     left_factors = []
#
# /Users/xizizhu/anaconda2/lib/python2.7/site-packages/patsy/desc.pyc in _check_interactable(expr)
#     268     if expr.intercept:
#     269         raise PatsyError("intercept term cannot interact with "
# --> 270                             "anything else", expr.intercept_origin)
#     271
#     272 def _interaction(left_expr, right_expr):
#
# PatsyError: intercept term cannot interact with anything else
#     SalePrice ~ Condition 2_Artery + Screen Porch + Garage Type_Detchd + House Style_2.5Fin + BsmtFin Type 1_BLQ + Garage Area + 2nd Flr SF + MS Zoning_RH + Bsmt Qual_Ex + Alley_Grvl + MS Zoning_RL + MS Zoning_RM + Condition 1_RRNe + Neighborhood_GrnHill + Garage Type_CarPort + Exterior 1st_MetalSd + Neighborhood_Landmrk + Condition 1_RRNn + Wood Deck SF + BsmtFin Type 2_GLQ + Overall Cond + MS SubClass_2-1/2 STORY ALL AGES + Land Contour_HLS + Bsmt Cond_Gd + BsmtFin Type 2_ALQ + Paved Drive_Y + Kitchen Qual_Po + Roof Matl_WdShngl + Paved Drive_P + Paved Drive_N + Bsmt Cond_TA + Bsmt Full Bath + Yr Sold + Neighborhood_NoRidge + Heating QC_Ex + Fireplace Qu_No Fireplace + Sale Type_COD + House Style_SLvl + Open Porch SF + Condition 2_RRAe + Pool Area + MS SubClass_1-STORY 1945 & OLDER + Fence_GdWo + Exter Qual_Ex + Neighborhood_BrkSide + Exterior 1st_CBlock + Garage Cond_Ex + BsmtFin Type 2_No Basement + Lot Config_CulDSac + Low Qual Fin SF + Bsmt Exposure_Av + Land Slope_Mod + Total Bsmt SF + Neighborhood_Mitchel + Bsmt Cond_Po + Neighborhood_Blueste + Exterior 1st_Wd Sdng + Exterior 1st_ImStucc + Fence_GdPrv + MS SubClass_2 FAMILY CONVERSION - ALL STYLES AND AGES + Functional_Sal + Lot Shape_IR2 + Neighborhood_ClearCr + Neighborhood_Edwards + Street_Grvl + Roof Matl_CompShg + Lot Config_FR2 + Lot Config_FR3 + Condition 1_Feedr + BsmtFin Type 2_Rec + Exterior 2nd_AsbShng + Fence_MnPrv + Sale Type_Con + Bsmt Exposure_No Basement + Bsmt Qual_TA + Sale Condition_Family + MS SubClass_PUD - MULTILEVEL - INCL SPLIT LEV/FOYER + 1st Flr SF + Exterior 2nd_Stone + Heating_Grav + Mas Vnr Type_BrkCmn + Bsmt Qual_Po + Condition 2_RRAn + Roof Style_Shed + Garage Finish_No Garage + Neighborhood_NAmes + Garage Type_Basment + Neighborhood_Blmngtn + Foundation_Stone + Heating_Wall + Sale Condition_Partial + Utilities_AllPub + BsmtFin Type 1_Rec + MS SubClass_2-STORY 1946 & NEWER + Exterior 1st_BrkFace + Year Remod/Add + Exter Cond_Ex + House Style_2.5Unf + Condition 2_RRNn + Heating QC_TA + Neighborhood_SWISU + Pool QC_No Pool + Fireplaces + Neighborhood_BrDale + Roof Style_Mansard + Roof Matl_Membran + Garage Cond_Gd + Exter Qual_Gd + Mas Vnr Type_CBlock + Exter Cond_Gd + Neighborhood_CollgCr + Neighborhood_Gilbert + Functional_Min2 + Neighborhood_SawyerW + Functional_Sev + Exter Cond_TA + Lot Shape_IR1 + Lot Shape_IR3 + BsmtFin Type 2_Unf + Land Contour_Lvl + Neighborhood_Sawyer + Mo Sold + Condition 2_Norm + Fireplace Qu_TA + Exterior 2nd_PreCast + 3Ssn Porch + BsmtFin Type 1_LwQ + Exterior 1st_VinylSd + Neighborhood_NWAmes + Roof Style_Gambrel + Roof Style_Hip + Exterior 2nd_AsphShn + Year Built + Electrical_SBrkr + Electrical_FuseF + Sale Type_VWD + Exterior 1st_Stucco + Neighborhood_IDOTRR + Half Bath + MS SubClass_1-1/2 STORY FINISHED ALL AGES + Neighborhood_Timber + Condition 1_PosA + Kitchen AbvGr + Foundation_Slab + Utilities_NoSeWa + Electrical_Mix + Lot Frontage + Mas Vnr Area + Condition 1_PosN + Sale Type_New + MS SubClass_DUPLEX - ALL STYLES AND AGES + Exterior 2nd_Stucco + Garage Qual_Po + Condition 1_Artery + BsmtFin SF 1 + BsmtFin SF 2 + Overall Qual + House Style_1Story + MS SubClass_1-STORY 1946 & NEWER ALL STYLES + Garage Qual_Ex + Heating_GasW + Heating_Floor + Enclosed Porch + MS Zoning_C (all) + Mas Vnr Type_None + Roof Matl_Metal + Exterior 2nd_CmentBd + Alley_Pave + MS SubClass_SPLIT FOYER + Kitchen Qual_Ex + Heating_GasA + MS SubClass_2-STORY PUD - 1946 & NEWER + Heating_OthW + Fireplace Qu_Ex + Exterior 1st_CemntBd + Neighborhood_NPkVill + Mas Vnr Type_Stone + Mas Vnr Type_BrkFace + Kitchen Qual_TA + House Style_2Story + Sale Type_ConLw + Sale Type_ConLI + Sale Type_ConLD + MS SubClass_SPLIT OR MULTI-LEVEL + Exterior 1st_BrkComm + Bsmt Exposure_No + Electrical_FuseP + Functional_Typ + Exterior 2nd_Wd Shng + Lot Config_Inside + BsmtFin Type 2_LwQ + Condition 2_PosA + Neighborhood_Greens + Garage Type_Attchd + Land Slope_Sev + Exterior 1st_AsphShn + Electrical_FuseA + Condition 2_PosN + Land Contour_Low + Neighborhood_ ...
#                                                                                                                                                                                                                                                                                                                                                                                                                          ^
